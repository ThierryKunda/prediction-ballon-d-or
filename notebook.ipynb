# %% [markdown]
# # Présentation du dataset

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
# import sklearn

# %%
from matplotlib import pyplot as plt
from matplotlib import cm

# %% [markdown]
# ## Affichage des 20 premiers joueurs

# %%
filename = 'dataset.csv'
dataset = pd.read_csv(filename, sep=";", header=0)
dataset.head(10)
# Out:
#    Rk             Player Nation Pos           Squad            Comp   Age  \
# 0   1         Max Aarons    ENG  DF    Norwich City  Premier League  22.0
# 1   2   Yunis Abdelhamid    MAR  DF           Reims         Ligue 1  34.0
# 2   3  Salis Abdul Samed    GHA  MF   Clermont Foot         Ligue 1  22.0
# 3   4    Laurent Abergel    FRA  MF         Lorient         Ligue 1  29.0
# 4   5        Charles Abi    FRA  FW   Saint-Etienne         Ligue 1  22.0
# 5   6     Dickson Abiama    NGA  FW  Greuther Fürth      Bundesliga  23.0
# 6   7     Matthis Abline    FRA  FW          Rennes         Ligue 1  19.0
# 7   8      Tammy Abraham    ENG  FW            Roma         Serie A  24.0
# 8   9         Luis Abram    PER  DF         Granada         La Liga  26.0
# 9  10   Francesco Acerbi    ITA  DF           Lazio         Serie A  34.0
#
#    Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon    OG  Recov  AerWon  \
# 0  2000  34      32  ...  0.03  1.41  1.16   0.00   0.06  0.03   5.53    0.47
# 1  1987  34      34  ...  0.00  0.06  1.39   0.00   0.03  0.00   6.77    2.02
# 2  2000  31      29  ...  0.00  0.36  1.24   0.00   0.00  0.00   8.76    0.88
# 3  1993  34      34  ...  0.03  0.79  2.23   0.00   0.00  0.00   8.87    0.43
# 4  2000   1       1  ...  0.00  2.00  0.00   0.00   0.00  0.00   4.00    2.00
# 5  1998  24       5  ...  1.85  0.25  0.86   0.00   0.00  0.00   4.81    2.72
# 6  2003   7       1  ...  0.00  0.91  0.00   0.00   0.00  0.00   6.36    0.00
# 7  1997  37      36  ...  0.50  0.70  0.64   0.03   0.03  0.00   3.67    2.39
# 8  1996   8       6  ...  0.00  0.00  0.97   0.00   0.00  0.16   4.03    1.94
# 9  1988  30      29  ...  0.14  0.04  0.43   0.04   0.00  0.00  10.70    2.84
#
#    AerLost  AerWon%
# 0     1.59     22.7
# 1     1.36     59.8
# 2     0.88     50.0
# 3     0.43     50.0
# 4     0.00    100.0
# 5     4.94     35.5
# 6     1.82      0.0
# 7     2.89     45.3
# 8     2.42     44.4
# 9     1.60     64.0
#
# [10 rows x 143 columns]

# %%
col_names = ['Goals','Assists', 'Blocks']
dataset.filter(col_names)[8:10]
# Out:
#    Goals  Assists  Blocks
# 8   0.00      0.0     2.1
# 9   0.14      0.0     1.7

# %%
dataset.describe()
# Out:
#                 Rk          Age         Born           MP       Starts  \
# count  2921.000000  2920.000000  2921.000000  2921.000000  2921.000000
# mean   1461.000000    26.092123  1994.725094    18.800068    13.749743
# std     843.364393     4.641746    37.210426    11.619882    11.393763
# min       1.000000    16.000000     0.000000     1.000000     0.000000
# 25%     731.000000    23.000000  1992.000000     8.000000     3.000000
# 50%    1461.000000    26.000000  1996.000000    20.000000    12.000000
# 75%    2191.000000    29.000000  1999.000000    29.000000    23.000000
# max    2921.000000    41.000000  2006.000000    38.000000    38.000000
#
#                Min          90s        Goals        Shots          SoT  ...  \
# count  2921.000000  2921.000000  2921.000000  2921.000000  2921.000000  ...
# mean   1234.756248    13.719069     0.111274     1.220431     0.391462  ...
# std     977.941288    10.865255     0.233688     1.511266     0.784754  ...
# min       1.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%     307.000000     3.400000     0.000000     0.280000     0.000000  ...
# 50%    1102.000000    12.200000     0.000000     0.820000     0.190000  ...
# 75%    2025.000000    22.500000     0.150000     1.830000     0.560000  ...
# max    3420.000000    38.000000     5.000000    20.000000    20.000000  ...
#
#                Off          Crs         TklW       PKwon        PKcon  \
# count  2921.000000  2921.000000  2921.000000  2921.00000  2921.000000
# mean      0.195029     1.063708     1.026689     0.01519     0.013050
# std       0.509935     1.341177     1.028466     0.21167     0.052864
# min       0.000000     0.000000     0.000000     0.00000     0.000000
# 25%       0.000000     0.000000     0.430000     0.00000     0.000000
# 50%       0.000000     0.590000     0.920000     0.00000     0.000000
# 75%       0.200000     1.700000     1.410000     0.00000     0.000000
# max      10.000000    15.000000    10.000000    10.00000     1.430000
#
#                 OG        Recov       AerWon      AerLost      AerWon%
# count  2921.000000  2921.000000  2921.000000  2921.000000  2921.000000
# mean      0.003451     7.410294     1.664286     1.858305    40.485861
# std       0.020306     3.650554     1.938046     2.245096    24.297290
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     5.070000     0.520000     0.840000    26.200000
# 50%       0.000000     7.380000     1.230000     1.390000    43.500000
# 75%       0.000000     9.380000     2.270000     2.210000    57.100000
# max       0.500000    40.000000    30.000000    40.000000   100.000000
#
# [8 rows x 138 columns]

# %% [markdown]
# ## Affichage de la première occurrence des lignes où le nom du joueur est dupliqué

# %%
dup = dataset.duplicated(subset='Player')
indexes_dup = list(dup[dup == True].index)
dataset.iloc[indexes_dup]
# Out:
#         Rk                     Player Nation   Pos       Squad  \
# 69      70                  Dele Alli    ENG  MFFW   Tottenham
# 82      83               Jordan Amavi    FRA    DF        Nice
# 86      87               Nadiem Amiri    GER  MFFW  Leverkusen
# 141    142  Pierre-Emerick Aubameyang    GAB    FW     Arsenal
# 219    220            Daniele Baselli    ITA    MF    Cagliari
# ...    ...                        ...    ...   ...         ...
# 2831  2832              Wout Weghorst    NED    FW   Wolfsburg
# 2859  2860                 Chris Wood    NZL    FW     Burnley
# 2872  2873               Okay Yoku�lu    TUR  DFMF      Getafe
# 2879  2880            Mattia Zaccagni    ITA    FW       Lazio
# 2883  2884              Denis Zakaria    SUI  MFDF  M'Gladbach
#
#                 Comp   Age  Born  MP  Starts  ...   Off   Crs  TklW  PKwon  \
# 69    Premier League  26.0  1996  10       8  ...  0.27  0.41  0.96   0.14
# 82           Ligue 1  28.0  1994   8       4  ...  0.00  1.52  1.09   0.00
# 86        Bundesliga  25.0  1996  13       3  ...  0.00  0.73  0.98   0.00
# 141   Premier League  32.0  1989  14      12  ...  0.87  0.78  0.61   0.00
# 219          Serie A  30.0  1992   9       2  ...  0.00  1.56  0.94   0.00
# ...              ...   ...   ...  ..     ...  ...   ...   ...   ...    ...
# 2831      Bundesliga  29.0  1992  18      17  ...  0.81  0.12  0.40   0.00
# 2859  Premier League  30.0  1991  17      17  ...  1.05  0.33  0.53   0.00
# 2872         La Liga  28.0  1994  11       5  ...  0.00  0.00  1.35   0.00
# 2879         Serie A  26.0  1995  29      21  ...  0.10  2.02  1.11   0.05
# 2883      Bundesliga  25.0  1996  16      15  ...  0.06  0.32  1.23   0.00
#
#       PKcon   OG  Recov  AerWon  AerLost  AerWon%
# 69     0.00  0.0   6.30    1.51     1.78     45.8
# 82     0.00  0.0  10.20    2.17     1.96     52.6
# 86     0.00  0.0   9.02    0.24     0.98     20.0
# 141    0.00  0.0   3.30    2.43     2.78     46.7
# 219    0.00  0.0  10.30    0.00     1.56      0.0
# ...     ...  ...    ...     ...      ...      ...
# 2831   0.00  0.0   4.74    3.12     2.66     54.0
# 2859   0.00  0.0   2.70    7.50     6.91     52.1
# 2872   0.00  0.0  11.00    3.08     1.35     69.6
# 2879   0.00  0.0   4.04    0.87     0.96     47.4
# 2883   0.06  0.0  10.90    0.90     0.97     48.3
#
# [135 rows x 143 columns]

# %%
dataset = dataset.drop_duplicates(subset=['Player', 'Rk'])
dataset.describe()
# Out:
#                 Rk          Age         Born           MP       Starts  \
# count  2921.000000  2920.000000  2921.000000  2921.000000  2921.000000
# mean   1461.000000    26.092123  1994.725094    18.800068    13.749743
# std     843.364393     4.641746    37.210426    11.619882    11.393763
# min       1.000000    16.000000     0.000000     1.000000     0.000000
# 25%     731.000000    23.000000  1992.000000     8.000000     3.000000
# 50%    1461.000000    26.000000  1996.000000    20.000000    12.000000
# 75%    2191.000000    29.000000  1999.000000    29.000000    23.000000
# max    2921.000000    41.000000  2006.000000    38.000000    38.000000
#
#                Min          90s        Goals        Shots          SoT  ...  \
# count  2921.000000  2921.000000  2921.000000  2921.000000  2921.000000  ...
# mean   1234.756248    13.719069     0.111274     1.220431     0.391462  ...
# std     977.941288    10.865255     0.233688     1.511266     0.784754  ...
# min       1.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%     307.000000     3.400000     0.000000     0.280000     0.000000  ...
# 50%    1102.000000    12.200000     0.000000     0.820000     0.190000  ...
# 75%    2025.000000    22.500000     0.150000     1.830000     0.560000  ...
# max    3420.000000    38.000000     5.000000    20.000000    20.000000  ...
#
#                Off          Crs         TklW       PKwon        PKcon  \
# count  2921.000000  2921.000000  2921.000000  2921.00000  2921.000000
# mean      0.195029     1.063708     1.026689     0.01519     0.013050
# std       0.509935     1.341177     1.028466     0.21167     0.052864
# min       0.000000     0.000000     0.000000     0.00000     0.000000
# 25%       0.000000     0.000000     0.430000     0.00000     0.000000
# 50%       0.000000     0.590000     0.920000     0.00000     0.000000
# 75%       0.200000     1.700000     1.410000     0.00000     0.000000
# max      10.000000    15.000000    10.000000    10.00000     1.430000
#
#                 OG        Recov       AerWon      AerLost      AerWon%
# count  2921.000000  2921.000000  2921.000000  2921.000000  2921.000000
# mean      0.003451     7.410294     1.664286     1.858305    40.485861
# std       0.020306     3.650554     1.938046     2.245096    24.297290
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     5.070000     0.520000     0.840000    26.200000
# 50%       0.000000     7.380000     1.230000     1.390000    43.500000
# 75%       0.000000     9.380000     2.270000     2.210000    57.100000
# max       0.500000    40.000000    30.000000    40.000000   100.000000
#
# [8 rows x 138 columns]

# %%
dataset.shape
# Out:
# (2921, 143)

# %% [markdown]
# ## Conversion des valeurs

# %%
# Affichage des types par colonnes
print(dataset.dtypes)
# Out:
# Rk           int64
# Player      object
# Nation      object
# Pos         object
# Squad       object
#             ...
# OG         float64
# Recov      float64
# AerWon     float64
# AerLost    float64
# AerWon%    float64
# Length: 143, dtype: object

# %%
dataset = dataset.convert_dtypes()
dataset.dtypes
# Out:
# Rk           Int64
# Player      string
# Nation      string
# Pos         string
# Squad       string
#             ...
# OG         Float64
# Recov      Float64
# AerWon     Float64
# AerLost    Float64
# AerWon%    Float64
# Length: 143, dtype: object

# %% [markdown]
# ## Vérification d'éléments *parasites*

# %% [markdown]
# ### Valeurs de types nulles

# %%
# On vérifie d'abord si au moins une valeur est nulle 
dataset.isnull().values.any()
# Out:
# True

# %%
# On affiche où sont les valeurs nulles
np.where(dataset.isnull())
# Out:
# (array([1531, 1531], dtype=int64), array([2, 6], dtype=int64))

# %%
# On compte le nombre de valeurs nulles
dataset.isnull().sum().sum()
# Out:
# 2

# %%
# On supprime les lignes qui contiennent nulles
dataset = dataset.dropna(axis=0)

# %%
dataset[dataset.notna()]
# Out:
#         Rk             Player Nation   Pos          Squad            Comp  \
# 0        1         Max Aarons    ENG    DF   Norwich City  Premier League
# 1        2   Yunis Abdelhamid    MAR    DF          Reims         Ligue 1
# 2        3  Salis Abdul Samed    GHA    MF  Clermont Foot         Ligue 1
# 3        4    Laurent Abergel    FRA    MF        Lorient         Ligue 1
# 4        5        Charles Abi    FRA    FW  Saint-Etienne         Ligue 1
# ...    ...                ...    ...   ...            ...             ...
# 2916  2917   Mart�n Zubimendi    ESP    MF  Real Sociedad         La Liga
# 2917  2918   Szymon ?urkowski    POL    MF         Empoli         Serie A
# 2918  2919    Martin �degaard    NOR    MF        Arsenal  Premier League
# 2919  2920        Milan ?uri?    BIH    FW    Salernitana         Serie A
# 2920  2921      Filip ?uri?i?    SRB  MFFW       Sassuolo         Serie A
#
#       Age  Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon    OG  Recov  \
# 0      22  2000  34      32  ...  0.03  1.41  1.16    0.0   0.06  0.03   5.53
# 1      34  1987  34      34  ...   0.0  0.06  1.39    0.0   0.03   0.0   6.77
# 2      22  2000  31      29  ...   0.0  0.36  1.24    0.0    0.0   0.0   8.76
# 3      29  1993  34      34  ...  0.03  0.79  2.23    0.0    0.0   0.0   8.87
# 4      22  2000   1       1  ...   0.0   2.0   0.0    0.0    0.0   0.0    4.0
# ...   ...   ...  ..     ...  ...   ...   ...   ...    ...    ...   ...    ...
# 2916   23  1999  36      26  ...   0.1   0.1  1.08    0.0    0.0   0.0   9.41
# 2917   24  1997  35      29  ...   0.0  0.74  1.91    0.0   0.04   0.0   8.05
# 2918   23  1998  36      32  ...   0.1  0.84  0.81    0.0   0.06   0.0   7.44
# 2919   32  1990  33      23  ...  0.25  0.29  0.17   0.04    0.0   0.0   3.24
# 2920   30  1992  12       9  ...  0.27   0.0  0.93    0.0    0.0   0.0   4.67
#
#       AerWon  AerLost  AerWon%
# 0       0.47     1.59     22.7
# 1       2.02     1.36     59.8
# 2       0.88     0.88     50.0
# 3       0.43     0.43     50.0
# 4        2.0      0.0    100.0
# ...      ...      ...      ...
# 2916    2.64     1.42     65.0
# 2917    1.02     1.56     39.4
# 2918    0.55     0.81     40.5
# 2919    12.4     4.81     72.0
# 2920     0.4     0.67     37.5
#
# [2920 rows x 143 columns]

# %% [markdown]
# ## Suppression de données non pertinentes pour le problème

# %% [markdown]
# ### Colonnes qui ne concernent pas directement le problème

# %%
# Liste à revoir
to_delete = ['Player', 'Nation', 'Squad', 'Age']
dataset = dataset.drop(columns=to_delete)

# %% [markdown]
# ### Colonnes à pourcentages

# %%
# On récupère la liste des colonnes dont le nom ne contient pas '%'
cols = [name for name in list(dataset.columns.values) if '%' not in name]
print(cols)
# Out:
# ['Rk', 'Pos', 'Comp', 'Born', 'MP', 'Starts', 'Min', '90s', 'Goals', 'Shots', 'SoT', 'G/Sh', 'G/SoT', 'ShoDist', 'ShoFK', 'ShoPK', 'PKatt', 'PasTotCmp', 'PasTotAtt', 'PasTotDist', 'PasTotPrgDist', 'PasShoCmp', 'PasShoAtt', 'PasMedCmp', 'PasMedAtt', 'PasLonCmp', 'PasLonAtt', 'Assists', 'PasAss', 'Pas3rd', 'PPA', 'CrsPA', 'PasProg', 'PasAtt', 'PasLive', 'PasDead', 'PasFK', 'TB', 'PasPress', 'Sw', 'PasCrs', 'CK', 'CkIn', 'CkOut', 'CkStr', 'PasGround', 'PasLow', 'PasHigh', 'PaswLeft', 'PaswRight', 'PaswHead', 'TI', 'PaswOther', 'PasCmp', 'PasOff', 'PasOut', 'PasInt', 'PasBlocks', 'SCA', 'ScaPassLive', 'ScaPassDead', 'ScaDrib', 'ScaSh', 'ScaFld', 'ScaDef', 'GCA', 'GcaPassLive', 'GcaPassDead', 'GcaDrib', 'GcaSh', 'GcaFld', 'GcaDef', 'Tkl', 'TklWon', 'TklDef3rd', 'TklMid3rd', 'TklAtt3rd', 'TklDri', 'TklDriAtt', 'TklDriPast', 'Press', 'PresSucc', 'PresDef3rd', 'PresMid3rd', 'PresAtt3rd', 'Blocks', 'BlkSh', 'BlkShSv', 'BlkPass', 'Int', 'Tkl+Int', 'Clr', 'Err', 'Touches', 'TouDefPen', 'TouDef3rd', 'TouMid3rd', 'TouAtt3rd', 'TouAttPen', 'TouLive', 'DriSucc', 'DriAtt', 'DriPast', 'DriMegs', 'Carries', 'CarTotDist', 'CarPrgDist', 'CarProg', 'Car3rd', 'CPA', 'CarMis', 'CarDis', 'RecTarg', 'Rec', 'RecProg', 'CrdY', 'CrdR', '2CrdY', 'Fls', 'Fld', 'Off', 'Crs', 'TklW', 'PKwon', 'PKcon', 'OG', 'Recov', 'AerWon', 'AerLost']

# %%
dataset = dataset.filter(items=cols)
dataset.shape
# Out:
# (2920, 129)

# %% [markdown]
# ### Ratios

# %%
cols = [name for name in list(dataset.columns.values) if '/' not in name]
print(cols)
# Out:
# ['Rk', 'Pos', 'Comp', 'Born', 'MP', 'Starts', 'Min', '90s', 'Goals', 'Shots', 'SoT', 'ShoDist', 'ShoFK', 'ShoPK', 'PKatt', 'PasTotCmp', 'PasTotAtt', 'PasTotDist', 'PasTotPrgDist', 'PasShoCmp', 'PasShoAtt', 'PasMedCmp', 'PasMedAtt', 'PasLonCmp', 'PasLonAtt', 'Assists', 'PasAss', 'Pas3rd', 'PPA', 'CrsPA', 'PasProg', 'PasAtt', 'PasLive', 'PasDead', 'PasFK', 'TB', 'PasPress', 'Sw', 'PasCrs', 'CK', 'CkIn', 'CkOut', 'CkStr', 'PasGround', 'PasLow', 'PasHigh', 'PaswLeft', 'PaswRight', 'PaswHead', 'TI', 'PaswOther', 'PasCmp', 'PasOff', 'PasOut', 'PasInt', 'PasBlocks', 'SCA', 'ScaPassLive', 'ScaPassDead', 'ScaDrib', 'ScaSh', 'ScaFld', 'ScaDef', 'GCA', 'GcaPassLive', 'GcaPassDead', 'GcaDrib', 'GcaSh', 'GcaFld', 'GcaDef', 'Tkl', 'TklWon', 'TklDef3rd', 'TklMid3rd', 'TklAtt3rd', 'TklDri', 'TklDriAtt', 'TklDriPast', 'Press', 'PresSucc', 'PresDef3rd', 'PresMid3rd', 'PresAtt3rd', 'Blocks', 'BlkSh', 'BlkShSv', 'BlkPass', 'Int', 'Tkl+Int', 'Clr', 'Err', 'Touches', 'TouDefPen', 'TouDef3rd', 'TouMid3rd', 'TouAtt3rd', 'TouAttPen', 'TouLive', 'DriSucc', 'DriAtt', 'DriPast', 'DriMegs', 'Carries', 'CarTotDist', 'CarPrgDist', 'CarProg', 'Car3rd', 'CPA', 'CarMis', 'CarDis', 'RecTarg', 'Rec', 'RecProg', 'CrdY', 'CrdR', '2CrdY', 'Fls', 'Fld', 'Off', 'Crs', 'TklW', 'PKwon', 'PKcon', 'OG', 'Recov', 'AerWon', 'AerLost']

# %%
dataset = dataset.filter(items=cols)
dataset.shape
# Out:
# (2920, 127)

# %% [markdown]
# ### Suppression des lignes avec le nombre de matchs joués inférieur ou égale à 15

# %%
# Liste des nombres de matchs joués
dataset['MP'][dataset['MP'] < 15]
# Out:
# 4        1
# 6        7
# 8        8
# 10      13
# 11       1
#         ..
# 2909     7
# 2910    10
# 2912     4
# 2914     1
# 2920    12
# Name: MP, Length: 1136, dtype: Int64

# %%
# Suppression
dataset = dataset[dataset['MP'] >= 15]
dataset
# Out:
#         Rk Pos            Comp  Born  MP  Starts   Min   90s  Goals  Shots  \
# 0        1  DF  Premier League  2000  34      32  2881  32.0    0.0   0.41
# 1        2  DF         Ligue 1  1987  34      34  2983  33.1   0.06   0.54
# 2        3  MF         Ligue 1  2000  31      29  2462  27.4   0.04   0.66
# 3        4  MF         Ligue 1  1993  34      34  2956  32.8    0.0   0.91
# 5        6  FW      Bundesliga  1998  24       5   726   8.1    0.0   2.22
# ...    ...  ..             ...   ...  ..     ...   ...   ...    ...    ...
# 2915  2916  DF         La Liga  1997  26      19  1648  18.3    0.0   0.49
# 2916  2917  MF         La Liga  1999  36      26  2591  28.8   0.07   0.73
# 2917  2918  MF         Serie A  1997  35      29  2307  25.6   0.23   1.84
# 2918  2919  MF  Premier League  1998  36      32  2785  30.9   0.23   1.72
# 2919  2920  FW         Serie A  1990  33      23  2165  24.1   0.21   2.07
#
#       ...   Fld   Off   Crs  TklW  PKwon  PKcon    OG  Recov  AerWon  AerLost
# 0     ...  1.84  0.03  1.41  1.16    0.0   0.06  0.03   5.53    0.47     1.59
# 1     ...  0.73   0.0  0.06  1.39    0.0   0.03   0.0   6.77    2.02     1.36
# 2     ...  1.28   0.0  0.36  1.24    0.0    0.0   0.0   8.76    0.88     0.88
# 3     ...  2.07  0.03  0.79  2.23    0.0    0.0   0.0   8.87    0.43     0.43
# 5     ...  1.48  1.85  0.25  0.86    0.0    0.0   0.0   4.81    2.72     4.94
# ...   ...   ...   ...   ...   ...    ...    ...   ...    ...     ...      ...
# 2915  ...  0.38  0.05  0.22  0.82    0.0   0.05   0.0   9.18    2.62     2.13
# 2916  ...  0.83   0.1   0.1  1.08    0.0    0.0   0.0   9.41    2.64     1.42
# 2917  ...  2.85   0.0  0.74  1.91    0.0   0.04   0.0   8.05    1.02     1.56
# 2918  ...  0.74   0.1  0.84  0.81    0.0   0.06   0.0   7.44    0.55     0.81
# 2919  ...  1.99  0.25  0.29  0.17   0.04    0.0   0.0   3.24    12.4     4.81
#
# [1784 rows x 127 columns]

# %% [markdown]
# ### Autres raisons (plus ou moins arbitraires)
# Voir le [mini-rapport](./IAS-projet-validation.pdf) de validation

# %%
# Suppression des colonnes trop précises
too_detailed = ['90s', 'ShoDist', 'ShoFK', 'ShoPK', 'PKatt', 'PasTotDist' , 'PasTotPrgDist', 'PasShoCmp',
                'PasShoAtt', 'PasMedCmp', 'PasMedAtt', 'PasLonCmp', 'PasLonAtt', 'Pas3rd', 'PPA',
                'CrsPA', 'PasProg', 'PasLive', 'PasDead', 'PasFK', 'TB', 'Sw',  'CkIn', 'CkOut',
                'CkStr', 'PasGround', 'PasLow', 'PasHigh', 'PaswLeft', 'PaswRight', 'PaswHead',
                'PaswOther', 'ScaPassLive', 'ScaPassDead', 'ScaSh', 'ScaFld', 'ScaDef', 'GcaPassLive',
                'GcaPassDead', 'GcaSh', 'TklDef3rd', 'TklMid3rd', 'TklAtt3rd', 'TklDriAtt', 'Press',
                'PresSucc', 'PresDef3rd', 'PresMid3rd', 'PresAtt3rd', 'BlkSh', 'BlkShSv', 'BlkPass',
                'Tkl+Int', 'TouDefPen', 'TouDef3rd', 'TouMid3rd', 'TouAtt3rd', 'TouAttPen', 'TouLive',
                'DriAtt', 'DriMegs', 'CarTotDist', 'CarPrgDist', 'CarProg', 'Car3rd', 'CPA', 'CarMis',
                'CarDis', 'RecTarg', 'Rec', 'RecProg']
print(len(too_detailed))
dataset = dataset.drop(too_detailed, axis=1)
dataset.columns.values
# Out:
# 71
# array(['Rk', 'Pos', 'Comp', 'Born', 'MP', 'Starts', 'Min', 'Goals',
#        'Shots', 'SoT', 'PasTotCmp', 'PasTotAtt', 'Assists', 'PasAss',
#        'PasAtt', 'PasPress', 'PasCrs', 'CK', 'TI', 'PasCmp', 'PasOff',
#        'PasOut', 'PasInt', 'PasBlocks', 'SCA', 'ScaDrib', 'GCA',
#        'GcaDrib', 'GcaFld', 'GcaDef', 'Tkl', 'TklWon', 'TklDri',
#        'TklDriPast', 'Blocks', 'Int', 'Clr', 'Err', 'Touches', 'DriSucc',
#        'DriPast', 'Carries', 'CrdY', 'CrdR', '2CrdY', 'Fls', 'Fld', 'Off',
#        'Crs', 'TklW', 'PKwon', 'PKcon', 'OG', 'Recov', 'AerWon',
#        'AerLost'], dtype=object)

# %% [markdown]
# # Visualisation

# %% [markdown]
# ## Valeurs catégorielles

# %%
# On rappelle la liste des features
print(dataset.columns.values, f"Nombre de features : {len(dataset.columns.values)}", sep="\n")
# Out:
# ['Rk' 'Pos' 'Comp' 'Born' 'MP' 'Starts' 'Min' 'Goals' 'Shots' 'SoT'
#  'PasTotCmp' 'PasTotAtt' 'Assists' 'PasAss' 'PasAtt' 'PasPress' 'PasCrs'
#  'CK' 'TI' 'PasCmp' 'PasOff' 'PasOut' 'PasInt' 'PasBlocks' 'SCA' 'ScaDrib'
#  'GCA' 'GcaDrib' 'GcaFld' 'GcaDef' 'Tkl' 'TklWon' 'TklDri' 'TklDriPast'
#  'Blocks' 'Int' 'Clr' 'Err' 'Touches' 'DriSucc' 'DriPast' 'Carries' 'CrdY'
#  'CrdR' '2CrdY' 'Fls' 'Fld' 'Off' 'Crs' 'TklW' 'PKwon' 'PKcon' 'OG'
#  'Recov' 'AerWon' 'AerLost']
# Nombre de features : 56

# %% [markdown]
# Il y en a beaucoup...

# %% [markdown]
# ### Répartition des joueurs dans les 5 grands championnats

# %%
# Nombre de joueurs par championnats
nb_par_champ = {
    "La Liga": len(dataset[dataset['Comp'] == "La Liga"]),
    "Ligue 1": len(dataset[dataset['Comp'] == "Ligue 1"]),
    "Premier League": len(dataset[dataset['Comp'] == "Premier League"]),
    "Serie A": len(dataset[dataset['Comp'] == "Serie A"]),
    "Bundesliga": len(dataset[dataset['Comp'] == "Serie A"]),
}
nb_par_champ
# Out:
# {'La Liga': 383,
#  'Ligue 1': 375,
#  'Premier League': 345,
#  'Serie A': 372,
#  'Bundesliga': 372}

# %%
fig, ax = plt.subplots()
# Taille de l'image
fig.set_size_inches(7,7)
# Etiquettes avec associations nom de la ligue - pourcentage du total (après nettoyage et encodage)
perc_labels = [f"{cmp} : {round(nb_par_champ[cmp]/dataset.shape[0]*100, 2)}%" for cmp in nb_par_champ]
# Diagramme circulaire
ax.pie(nb_par_champ.values(), frame=True, center=(4,4), radius=2, labels=perc_labels)
# Paramétrages des axes
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()

# %% [markdown]
# On remarque bien que l'on a retiré les valeurs de manière équilibrée par rapport à la répartition entre chaque championnat

# %% [markdown]
# ### Répartition des joueurs au niveau des postes

# %%
set(dataset["Pos"])
# Out:
# {'DF', 'DFFW', 'DFMF', 'FW', 'FWDF', 'FWMF', 'GK', 'MF', 'MFDF', 'MFFW'}

# %%
noms_postes = set(dataset["Pos"])
postes = {nom: len(dataset[dataset["Pos"] == nom]) for nom in noms_postes}
postes
# Out:
# {'DFFW': 18,
#  'DF': 601,
#  'MFDF': 40,
#  'MFFW': 143,
#  'FWDF': 15,
#  'DFMF': 34,
#  'FW': 238,
#  'GK': 109,
#  'MF': 387,
#  'FWMF': 199}

# %% [markdown]
# On remarque déjà qu'il n'y a qu'une seule occurrence pour le poste de GKMF (GoalKeeper Midfielder ?).
# On le supprimera plus tard dans le dataset car trop rare.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12,12)
perc_labels = [f"{p} : {round(postes[p]/dataset.shape[0]*100, 2)}%" for p in postes]
ax.pie(postes.values(), frame=True, center=(4,4), radius=2, labels=perc_labels)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()

# %% [markdown]
# On remarque plusieurs choses :
# - le poste de défenseur (`DF`) est prédominante, suivi de milieu de terrain (`MF`) et de arrière latéral-défenseur latéral
# - il y a des mélanges de postes pour indiquer (on imagine) que le joueur peut occuper/a déjà occupé plusieurs postes ou rôles (voire de manière fréquente)
# - il y a trop peu de gardien

# %% [markdown]
# ## Quelques valeurs numériques

# %% [markdown]
# ### Buts, passes décisives, arrêts

# %%
dataset.filter(['MP','Goals','Assists', 'Blocks'])
# Out:
#       MP  Goals  Assists  Blocks
# 0     34    0.0     0.06    2.69
# 1     34   0.06      0.0    1.87
# 2     31   0.04      0.0    0.99
# 3     34    0.0     0.06    1.68
# 5     24    0.0     0.12    1.23
# ...   ..    ...      ...     ...
# 2915  26    0.0     0.05    1.48
# 2916  36   0.07     0.03    1.35
# 2917  35   0.23     0.08    2.03
# 2918  36   0.23     0.13    0.58
# 2919  33   0.21     0.17    0.41
#
# [1784 rows x 4 columns]

# %%
plt.style.use('_mpl-gallery')

# Diagramme de dispersion
player_numbers = list(dataset.iloc[:, 0])
xs = list(dataset['Goals'])
ys = list(dataset['Assists'])
zs = list(dataset['Blocks'])
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.set_size_inches(10,10)
remarquables = []
ax.scatter(xs, ys, zs, c='#000', marker='x')
for infos in zip(player_numbers, xs, ys, zs):
    if infos[1] >= 1 or infos[2] >= 0.5 or infos[3] >= 3 or (infos[1] >= 0.5 and infos[2] >= 1) or (infos[2] >= 1 and infos[2] >= 1):
        remarquables.append(infos[0])
        ax.text(infos[1], infos[2], infos[3], str(infos[0]), fontdict={"fontsize": 12, "color": "blue"}, zdir='x')
# for infos in zip(xs, ys, zs):
#     ax.text(infos[0], infos[1], infos[2], f"Joueur n° {0}", fontdict={"fontsize": 12, "color": "r"}, zdir='x')
    
ax.set_xlabel("Goals")
ax.set_ylabel("Assists")
ax.set_zlabel("Blocks")
ax.view_init(20, 60)
fig.tight_layout()
plt.show()

# %%
df_orig = pd.read_csv(filename, sep=";", header=0)

# %%
df_orig[np.in1d(df_orig['Rk'], remarquables)][['Rk', 'Player', 'Pos', 'Goals', 'Assists', 'Blocks']]
# Out:
#         Rk               Player   Pos  Goals  Assists  Blocks
# 45      46       Kevin Akpoguma    DF   0.12     0.12    3.29
# 532    533     Max Christiansen    MF   0.00     0.00    3.03
# 657    658  Romain Del Castillo  MFFW   0.00     0.56    1.39
# 669    670      Ousmane Demb�l�    FW   0.06     0.83    0.70
# 1117  1118       Erling Haaland    FW   1.04     0.38    0.57
# 1139  1140        Abdou Harroui    MF   0.00     0.00    3.00
# 1289  1290          Ben Johnson    DF   0.06     0.00    3.16
# 1304  1305           Luka Jovi?    FW   0.24     0.73    0.49
# 1445  1446     Dejan Kulusevski  MFFW   0.36     0.57    0.79
# 1512  1513   Robert Lewandowski    FW   1.07     0.09    0.73
# 1542  1543       Banzouzi Locko  DFMF   0.09     0.09    3.04
# 1720  1721        Kylian Mbapp�    FW   0.83     0.54    0.15
# 1774  1775         Lionel Messi  FWMF   0.25     0.59    0.33
# 1806  1807    Aleksei Miranchuk  MFFW   0.23     0.58    0.81
# 1869  1870        Thomas M�ller    MF   0.28     0.63    1.34
# 2149  2150           Paul Pogba  MFFW   0.07     0.60    1.07
# 2423  2424         Louis Schaub  MFFW   0.14     0.27    3.15
# 2425  2426        Patrik Schick    FW   1.04     0.13    0.52
# 2426  2427   Kingsley Schindler  DFMF   0.26     0.51    1.03
# 2534  2535         Alberto Soro  MFFW   0.00     0.00    3.91
# 2586  2587        Isaac Success    FW   0.20     0.59    0.69
# 2619  2620       Charlie Taylor    DF   0.00     0.10    3.14

# %% [markdown]
# ### Rééquilibrage du jeu de données
#
# Pour rééquilibrer le jeu de données, on va dupliquer de façon homogène les lignes
# jusqu'à avoir à peu près le même nombre de joueurs à chaque poste,
# en prenant le poste majoritaire comme taille référence.

# %%
# Nombre total de joueurs
dataset.shape[0]
# Out:
# 1784

# %%
# "Tailles" relatives des "DF" par rapport aux autres postes
ratios = {p: round(postes["DF"]/postes[p]) for p in postes if p != "DF"}
ratios
# Out:
# {'DFFW': 33,
#  'MFDF': 15,
#  'MFFW': 4,
#  'FWDF': 40,
#  'DFMF': 18,
#  'FW': 3,
#  'GK': 6,
#  'MF': 2,
#  'FWMF': 3}

# %% [markdown]
# Soit $p$ un poste (autre que `DF`), à partir de $r = \frac{|p|}{|poste_{DF}|}$, on sait que la nouvelle taille du poste $p$ est $p\leftarrow r*p$.

# %%
def dupl_homogene(dataset: DataFrame, colonne_maj: str, ratios: dict[str, int]) -> DataFrame:
    dupl: list[Series] = []
    for p in ratios:
        for _ in range(ratios[p]):
            df = dataset[dataset['Pos'] == p].copy(deep=True)
            # print(df)
            # print(list(ligne))
            dupl.append(df)
    dupl.append(dataset[dataset['Pos'] == colonne_maj])
    # print(dupl)
    return pd.concat(dupl, axis=0)

# %%
dataset.shape
# Out:
# (1784, 56)

# %%
dataset_equi = dupl_homogene(dataset, "DF", ratios)
dataset_equi
# Out:
#         Rk   Pos            Comp  Born  MP  Starts   Min  Goals  Shots   SoT  \
# 177    178  DFFW      Bundesliga  1998  34      28  2446   0.11   1.36  0.29
# 587    588  DFFW      Bundesliga  2001  21      11  1079    0.0   1.08  0.25
# 683    684  DFFW         La Liga  2000  21      17  1512    0.0   0.71  0.18
# 898    899  DFFW         Serie A  1991  24      12  1152   0.16   1.72  0.47
# 1179  1180  DFFW      Bundesliga  1991  23       5   754    0.0   1.79  0.48
# ...    ...   ...             ...   ...  ..     ...   ...    ...    ...   ...
# 2895  2896    DF         Ligue 1  1995  38      37  3337    0.0   0.86  0.16
# 2905  2906    DF         Serie A  2000  20      13  1314    0.0   0.41  0.21
# 2907  2908    DF  Premier League  1996  15      10  1047    0.0   1.03  0.34
# 2913  2914    DF  Premier League  1994  24      24  2078   0.04    0.3  0.09
# 2915  2916    DF         La Liga  1997  26      19  1648    0.0   0.49  0.11
#
#       ...   Fld   Off   Crs  TklW  PKwon  PKcon    OG  Recov  AerWon  AerLost
# 177   ...   1.4  0.37   2.5  1.25    0.0    0.0   0.0   8.16     1.1      1.4
# 587   ...  1.42   0.5  1.08  1.08    0.0    0.0   0.0   5.75    0.92     1.42
# 683   ...  1.61  0.06  3.33  1.43    0.0    0.0   0.0   6.49    0.65     0.83
# 898   ...  0.63  0.23  2.42  1.25    0.0    0.0   0.0   8.91    1.02     0.78
# 1179  ...  1.31  0.48  3.69  0.83    0.0    0.0   0.0   7.14    0.36     0.83
# ...   ...   ...   ...   ...   ...    ...    ...   ...    ...     ...      ...
# 2895  ...  2.45  0.13   2.4  1.13    0.0   0.03   0.0   9.06    0.78     0.97
# 2905  ...  0.41  0.07  0.27  0.68    0.0   0.07   0.0   8.63    4.18      2.4
# 2907  ...  0.34  0.09  2.41  0.95    0.0    0.0   0.0   9.83    1.47     1.38
# 2913  ...  0.43   0.0  0.09  0.22    0.0    0.0  0.04    7.1    2.38     1.08
# 2915  ...  0.38  0.05  0.22  0.82    0.0   0.05   0.0   9.18    2.62     2.13
#
# [6318 rows x 56 columns]

# %%
postes_equi = {nom: len(dataset_equi[dataset_equi["Pos"] == nom]) for nom in noms_postes}
postes_equi
# Out:
# {'DFFW': 594,
#  'DF': 601,
#  'MFDF': 600,
#  'MFFW': 572,
#  'FWDF': 600,
#  'DFMF': 612,
#  'FW': 714,
#  'GK': 654,
#  'MF': 774,
#  'FWMF': 597}

# %%
# Visualisation
fig, ax = plt.subplots()
fig.set_size_inches(12,12)
perc_labels = [f"{p} : {round(postes_equi[p]/dataset_equi.shape[0]*100, 2)}%" for p in postes_equi]
ax.pie(postes_equi.values(), frame=True, center=(4,4), radius=2, labels=perc_labels)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()

# %% [markdown]
# # Encodage des données

# %% [markdown]
# ## Encodage 1-hot avec suppression de la première catégorielle

# %%
dataset_equi = pd.get_dummies(dataset_equi, drop_first=True)

# %%
def get_cat_values(data: DataFrame, feature_name: str) -> list[str]:
    """Récupère les valeurs catégorielles à partir du nom de la colonne après un encodage 1-hot.\n
    En cas de encodage à k-1 valeurs, la valeur non explicite ne sera pas récupérée
    """
    feature = []
    for name in data.columns.values:
        if name.startswith(feature_name):
            feature.append(name)
    return [ft.replace(feature_name+"_", "") for ft in feature]

# %%
# Position du joueur
get_cat_values(dataset_equi, "Pos")
# Out:
# ['DFFW', 'DFMF', 'FW', 'FWDF', 'FWMF', 'GK', 'MF', 'MFDF', 'MFFW']

# %%
# Championnat du club du joueur
get_cat_values(dataset_equi, "Comp")
# Out:
# ['La Liga', 'Ligue 1', 'Premier League', 'Serie A']

# %% [markdown]
# # Système de score
# Plutôt que de directement partir du jeu de données pour réaliser la tâche que l'on a définit au départ,
# on va plutôt définir un système de score qui associera à chaque joueur un score sur lequel l'apprentissage sera appliqué.
# Ce score sera défini par un ensemble nouveau de colonnes qui correspond aux features auxquels on a associé un poids.
#
# Par exemple : en considérant les buts comme très positives à l'appréciation du joueur et les fautes comme pénalisants, on peut ainsi
# appliquer les calculs suivants :
# - score des buts = 3 * le nombre de but
# - score des fautes = -2 * le nombre de fautes

# %% [markdown]
# ## Definition de la fonction de poids

# %%
from typing import Callable, Union, Literal
from math import log10, sqrt

# %%
def nombre_a_la_puissance_10(x: float, seuil_puiss_10: int):
    puiss_diff = 0
    if x != 0:
        puiss_diff = seuil_puiss_10 - round(log10(abs(x)))
    return x * (10**puiss_diff)

# %%
def genere_poids(
        dataset: DataFrame, poids_map: dict[str, Callable[[Union[int, float]], float]],
        defaut: Callable[[Union[int,float]], float] = lambda _: 0,
        seuil_puiss_10: int = 1,
        supprime_non_def: bool = False,
        trie: bool = False
        ) -> DataFrame:
    """Renvoie le jeu de données avec des colonnes scores pour chaque feature."""
    df = dataset.copy(deep=True)
    for ft in poids_map:
        df[ft] = df[ft].apply(poids_map[ft])
        df[ft] = df[ft].apply(lambda x: nombre_a_la_puissance_10(x, seuil_puiss_10))
    # Poids non définis -> appliquer la fonction de défaut
    autres = set(dataset) - set(poids_map)
    for ft in autres:
        df[ft] = df[ft].apply(defaut)
        df[ft] = df[ft].apply(lambda x: nombre_a_la_puissance_10(x, seuil_puiss_10))
    # Suppression des poids non définis (selon le paramètre supprime_non_def)
    if supprime_non_def:
        df = df.drop(list(autres), axis=1)
    df.insert(0, "Total", df.sum(axis=1))
    if trie:
        return df.sort_values(by=['Total'], ascending=False)
    return df

# %%
dataset_equi[['Goals', 'Fls', 'Assists']]
# Out:
#       Goals   Fls  Assists
# 177    0.11  1.25     0.18
# 587     0.0  2.08     0.08
# 683     0.0  1.01     0.18
# 898    0.16  0.86      0.0
# 1179    0.0  0.95     0.48
# ...     ...   ...      ...
# 2895    0.0  0.78     0.08
# 2905    0.0   1.3      0.0
# 2907    0.0  0.95     0.34
# 2913   0.04  0.52      0.0
# 2915    0.0  1.42     0.05
#
# [6318 rows x 3 columns]

# %%
pm = {
    "Goals": lambda x: 3 * x,
    "Fls": lambda x: -sqrt(x),
}
genere_poids(dataset_equi, pm)[['Goals', 'Fls', 'Assists']]
# Out:
#       Goals        Fls  Assists
# 177     3.3 -11.180340        0
# 587     0.0 -14.422205        0
# 683     0.0 -10.049876        0
# 898     4.8  -9.273618        0
# 1179    0.0  -9.746794        0
# ...     ...        ...      ...
# 2895    0.0  -8.831761        0
# 2905    0.0 -11.401754        0
# 2907    0.0  -9.746794        0
# 2913   12.0  -7.211103        0
# 2915    0.0 -11.916375        0
#
# [6318 rows x 3 columns]

# %%
dataset.columns.values
# Out:
# array(['Rk', 'Pos', 'Comp', 'Born', 'MP', 'Starts', 'Min', 'Goals',
#        'Shots', 'SoT', 'PasTotCmp', 'PasTotAtt', 'Assists', 'PasAss',
#        'PasAtt', 'PasPress', 'PasCrs', 'CK', 'TI', 'PasCmp', 'PasOff',
#        'PasOut', 'PasInt', 'PasBlocks', 'SCA', 'ScaDrib', 'GCA',
#        'GcaDrib', 'GcaFld', 'GcaDef', 'Tkl', 'TklWon', 'TklDri',
#        'TklDriPast', 'Blocks', 'Int', 'Clr', 'Err', 'Touches', 'DriSucc',
#        'DriPast', 'Carries', 'CrdY', 'CrdR', '2CrdY', 'Fls', 'Fld', 'Off',
#        'Crs', 'TklW', 'PKwon', 'PKcon', 'OG', 'Recov', 'AerWon',
#        'AerLost'], dtype=object)

# %%
PM = {
    "Goals": lambda x: 3 * x,
    "Assists": lambda x: 2 * x,
    "Blocks": lambda x: x,
    "Fls": lambda x: -x/2,
    "PasCmp": lambda x: x/5,
    "GCA": lambda x: x/4,
}

# %%
# Initialisation du dataset de points
dataset_score = genere_poids(dataset_equi, PM, supprime_non_def=True, trie=True)
dataset_score
# Out:
#        Total  Goals  Assists  PasCmp    GCA  Blocks    Fls
# 2425  101.60   31.2     26.0   25.20  17.25     5.2  -3.25
# 2425  101.60   31.2     26.0   25.20  17.25     5.2  -3.25
# 2425  101.60   31.2     26.0   25.20  17.25     5.2  -3.25
# 152    93.51   24.0     16.0    9.66  30.00    19.4  -5.55
# 1689   91.60   24.9     24.0   31.40   9.75     9.8  -8.25
# ...      ...    ...      ...     ...    ...     ...    ...
# 369   -25.98    0.0      0.0    4.02   0.00     0.0 -30.00
# 369   -25.98    0.0      0.0    4.02   0.00     0.0 -30.00
# 369   -25.98    0.0      0.0    4.02   0.00     0.0 -30.00
# 369   -25.98    0.0      0.0    4.02   0.00     0.0 -30.00
# 369   -25.98    0.0      0.0    4.02   0.00     0.0 -30.00
#
# [6318 rows x 7 columns]

# %%
def podium_pourcent(dataset: DataFrame, taille_podium: int) -> DataFrame:
    df = dataset.copy(deep=True)
    classement = []
    # Nouvelle colonne "classement" : [0, 0, ..., 0, 1, 1, ..., 1, ..., taille_podium-1]
    nb_par_podium = dataset.shape[0] // taille_podium
    for i in range(nb_par_podium):
        classement += [i] * taille_podium
    reste_indice_debut = classement[-1] * nb_par_podium
    reste = dataset.shape[0] % taille_podium
    classement += ([reste_indice_debut] * reste)
    df.insert(0, "Classement", classement)
    # On remet les lignes dans l'ordre de l'index -> ordre du début
    df.sort_index(axis=0, inplace=True)
    return df

# %%
TAILLE_PODIUM = 20

# %%
dataset_classement = podium_pourcent(dataset_score, TAILLE_PODIUM)

# %%
dataset_classement.head(25)
# Out:
#     Classement  Total  Goals  Assists  PasCmp    GCA  Blocks    Fls
# 0          122  44.85    0.0     12.0    6.80   4.00    26.9  -4.85
# 1          121  45.44   18.0      0.0    7.74   7.50    18.7  -6.50
# 2          194  34.88   12.0      0.0   11.18  10.00     9.9  -8.20
# 2          194  34.88   12.0      0.0   11.18  10.00     9.9  -8.20
# 3          203  33.69    0.0     12.0    8.14   3.75    16.8  -7.00
# 3          203  33.69    0.0     12.0    8.14   3.75    16.8  -7.00
# 5           73  53.65    0.0     24.0   22.20   6.25    12.3 -11.10
# 5           73  53.65    0.0     24.0   22.20   6.25    12.3 -11.10
# 5           73  53.65    0.0     24.0   22.20   6.25    12.3 -11.10
# 7            2  80.30   15.0     24.0   29.20   8.75     9.6  -6.25
# 7            3  80.30   15.0     24.0   29.20   8.75     9.6  -6.25
# 7            3  80.30   15.0     24.0   29.20   8.75     9.6  -6.25
# 9          103  48.01    4.2      0.0   12.86  17.50    17.0  -3.55
# 12           1  84.61   12.0     24.0   12.46  30.00    14.3  -8.15
# 13           8  73.55    9.3     26.0   29.60   4.50    11.0  -6.85
# 13           8  73.55    9.3     26.0   29.60   4.50    11.0  -6.85
# 13           8  73.55    9.3     26.0   29.60   4.50    11.0  -6.85
# 14         117  45.96    0.0     14.0   10.56   6.75    21.3  -6.65
# 14         117  45.96    0.0     14.0   10.56   6.75    21.3  -6.65
# 17          20  67.75    6.3     28.0    5.60  12.50    25.0  -9.65
# 17          20  67.75    6.3     28.0    5.60  12.50    25.0  -9.65
# 17          20  67.75    6.3     28.0    5.60  12.50    25.0  -9.65
# 18         100  48.76   12.0      5.6    7.26  13.00    16.3  -5.40
# 18         100  48.76   12.0      5.6    7.26  13.00    16.3  -5.40
# 18         100  48.76   12.0      5.6    7.26  13.00    16.3  -5.40

# %% [markdown]
# # Entrainement sans pré-traitement

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import completeness_score, homogeneity_score
from sklearn.model_selection import train_test_split

# %%
def train_valid_test_split(
        dataset: DataFrame, test_label: str, test_size: float,
        validation_size: float, rand_states: dict[Literal['validation', 'test'], float] = None
        ) -> tuple[DataFrame, DataFrame, DataFrame, Series, Series, Series]:
    if not rand_states:
        rand_states = {"validation": None, "test": None}
    # Premier séparation autre - test
    X_train, X_test, y_train, y_test = train_test_split(
        dataset.drop(test_label, axis=1),
        dataset[test_label],
        test_size=test_size,
        random_state=rand_states["test"]
    )
    # 2è séparation entrainement - validation
    X_train, X_val, y_train, y_val = train_test_split(
        X_train,
        y_train,
        # Remarque : valid_sur_autre = valid_tot / autre
        test_size=validation_size/(1-test_size),
        random_state=rand_states["validation"]
    )
    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
# rnd = {"validation": 25, 'test': 50}
X_train, X_val, _, y_train, y_val, _ = train_valid_test_split(dataset_classement, "Classement", 0.1, 0.4)
# y_train, y_val, y_test

# %%
# On veut des clusters avec une taille pré-définie
kmeans = KMeans(len(X_train) // TAILLE_PODIUM, n_init='auto', random_state=40).fit(X_train)
# kmeans.labels_

# %%
y_pred = kmeans.predict(X_val)

# %%
# Vérifie que les points que les points de données de même classe appartiennent au même cluster
completeness_score(y_val, y_pred)
# Out:
# 0.7820948875765239

# %%
homogeneity_score(y_val, y_pred)
# Out:
# 0.6513487784070081

# %% [markdown]
# On arrive à des scores autour de 0,6 et 0,8.

# %% [markdown]
# # Entrainement après pré-traitement

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ## Normalisation

# %%
scaler = StandardScaler()
scaler.fit(dataset_classement.drop("Classement", axis=1))
# Out:
# StandardScaler()

# %%
# Moyenne de chaque feature
scaler.mean_
# Out:
# array([39.47031814,  7.90085945,  8.72928142,  8.51620133,  9.15716999,
#        13.78659861, -8.61979266])

# %%
noms_feat = list(dataset_classement)
noms_feat.remove("Classement")
df_transform = scaler.transform(dataset_classement.drop("Classement", axis=1))
# np.transpose(df_transform)
dataset_std = DataFrame(dict(zip(noms_feat, np.transpose(df_transform))))

# %%
# dataset_classement['Classement']
dataset_std
# Out:
#          Total     Goals   Assists    PasCmp       GCA    Blocks       Fls
# 0     0.274605 -0.934919  0.362412 -0.284016 -0.682077  1.898697  0.614943
# 1     0.304721  1.195045 -0.967248 -0.128454 -0.219174  0.711414  0.345789
# 2    -0.234312  0.485057 -0.967248  0.440835  0.111471 -0.562743  0.068478
# 3    -0.234312  0.485057 -0.967248  0.440835  0.111471 -0.562743  0.068478
# 4    -0.295055 -0.934919  0.362412 -0.062258 -0.715141  0.436312  0.264227
# ...        ...       ...       ...       ...       ...       ...       ...
# 6313  0.641106 -0.118433  1.913681  0.043656  0.078407 -1.156385  0.557850
# 6314  0.641106 -0.118433  1.913681  0.043656  0.078407 -1.156385  0.557850
# 6315 -1.014787 -0.189432 -0.590511 -0.823517 -0.119980 -1.402529  0.427351
# 6316 -1.014787 -0.189432 -0.590511 -0.823517 -0.119980 -1.402529  0.427351
# 6317 -1.014787 -0.189432 -0.590511 -0.823517 -0.119980 -1.402529  0.427351
#
# [6318 rows x 7 columns]

# %% [markdown]
# ## PCA

# %%
pca = PCA(n_components=2)
pca.fit(dataset_std)
# Out:
# PCA(n_components=2)

# %%
dataset_pre_proc = pca.transform(dataset_std)

# %%
dataset_pre_proc = DataFrame(dataset_pre_proc)
dataset_pre_proc
# Out:
#              0         1
# 0     0.236054  0.162079
# 1     0.370091  0.417951
# 2    -0.365539 -0.234336
# 3    -0.365539 -0.234336
# 4    -0.502636 -0.317371
# ...        ...       ...
# 6313  0.960874 -1.242648
# 6314  0.960874 -1.242648
# 6315 -1.578115 -0.556688
# 6316 -1.578115 -0.556688
# 6317 -1.578115 -0.556688
#
# [6318 rows x 2 columns]
