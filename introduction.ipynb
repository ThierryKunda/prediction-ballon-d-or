# %% [markdown]
# # Première visualisation du dataset

# %%
import numpy as np
import pandas as pd
# import sklearn

# %%
from matplotlib import pyplot as plt
from matplotlib import cm

# %% [markdown]
# ## Affichage des 20 premiers joueurs

# %%
filename = 'dataset.csv'
dataset = pd.read_csv(filename, sep=";", header=0)
dataset.head(10)
# Out:
#    Rk             Player Nation Pos           Squad            Comp   Age  \
# 0   1         Max Aarons    ENG  DF    Norwich City  Premier League  22.0
# 1   2   Yunis Abdelhamid    MAR  DF           Reims         Ligue 1  34.0
# 2   3  Salis Abdul Samed    GHA  MF   Clermont Foot         Ligue 1  22.0
# 3   4    Laurent Abergel    FRA  MF         Lorient         Ligue 1  29.0
# 4   5        Charles Abi    FRA  FW   Saint-Etienne         Ligue 1  22.0
# 5   6     Dickson Abiama    NGA  FW  Greuther Fürth      Bundesliga  23.0
# 6   7     Matthis Abline    FRA  FW          Rennes         Ligue 1  19.0
# 7   8      Tammy Abraham    ENG  FW            Roma         Serie A  24.0
# 8   9         Luis Abram    PER  DF         Granada         La Liga  26.0
# 9  10   Francesco Acerbi    ITA  DF           Lazio         Serie A  34.0
#
#    Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon    OG  Recov  AerWon  \
# 0  2000  34      32  ...  0.03  1.41  1.16   0.00   0.06  0.03   5.53    0.47
# 1  1987  34      34  ...  0.00  0.06  1.39   0.00   0.03  0.00   6.77    2.02
# 2  2000  31      29  ...  0.00  0.36  1.24   0.00   0.00  0.00   8.76    0.88
# 3  1993  34      34  ...  0.03  0.79  2.23   0.00   0.00  0.00   8.87    0.43
# 4  2000   1       1  ...  0.00  2.00  0.00   0.00   0.00  0.00   4.00    2.00
# 5  1998  24       5  ...  1.85  0.25  0.86   0.00   0.00  0.00   4.81    2.72
# 6  2003   7       1  ...  0.00  0.91  0.00   0.00   0.00  0.00   6.36    0.00
# 7  1997  37      36  ...  0.50  0.70  0.64   0.03   0.03  0.00   3.67    2.39
# 8  1996   8       6  ...  0.00  0.00  0.97   0.00   0.00  0.16   4.03    1.94
# 9  1988  30      29  ...  0.14  0.04  0.43   0.04   0.00  0.00  10.70    2.84
#
#    AerLost  AerWon%
# 0     1.59     22.7
# 1     1.36     59.8
# 2     0.88     50.0
# 3     0.43     50.0
# 4     0.00    100.0
# 5     4.94     35.5
# 6     1.82      0.0
# 7     2.89     45.3
# 8     2.42     44.4
# 9     1.60     64.0
#
# [10 rows x 143 columns]

# %%
col_names = ['Goals','Assists', 'Blocks']
dataset.filter(col_names)[8:10]
# Out:
#    Goals  Assists  Blocks
# 8   0.00      0.0     2.1
# 9   0.14      0.0     1.7

# %%
dataset.describe()
# Out:
#                 Rk          Age         Born           MP       Starts  \
# count  2921.000000  2920.000000  2921.000000  2921.000000  2921.000000
# mean   1461.000000    26.092123  1994.725094    18.800068    13.749743
# std     843.364393     4.641746    37.210426    11.619882    11.393763
# min       1.000000    16.000000     0.000000     1.000000     0.000000
# 25%     731.000000    23.000000  1992.000000     8.000000     3.000000
# 50%    1461.000000    26.000000  1996.000000    20.000000    12.000000
# 75%    2191.000000    29.000000  1999.000000    29.000000    23.000000
# max    2921.000000    41.000000  2006.000000    38.000000    38.000000
#
#                Min          90s        Goals        Shots          SoT  ...  \
# count  2921.000000  2921.000000  2921.000000  2921.000000  2921.000000  ...
# mean   1234.756248    13.719069     0.111274     1.220431     0.391462  ...
# std     977.941288    10.865255     0.233688     1.511266     0.784754  ...
# min       1.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%     307.000000     3.400000     0.000000     0.280000     0.000000  ...
# 50%    1102.000000    12.200000     0.000000     0.820000     0.190000  ...
# 75%    2025.000000    22.500000     0.150000     1.830000     0.560000  ...
# max    3420.000000    38.000000     5.000000    20.000000    20.000000  ...
#
#                Off          Crs         TklW       PKwon        PKcon  \
# count  2921.000000  2921.000000  2921.000000  2921.00000  2921.000000
# mean      0.195029     1.063708     1.026689     0.01519     0.013050
# std       0.509935     1.341177     1.028466     0.21167     0.052864
# min       0.000000     0.000000     0.000000     0.00000     0.000000
# 25%       0.000000     0.000000     0.430000     0.00000     0.000000
# 50%       0.000000     0.590000     0.920000     0.00000     0.000000
# 75%       0.200000     1.700000     1.410000     0.00000     0.000000
# max      10.000000    15.000000    10.000000    10.00000     1.430000
#
#                 OG        Recov       AerWon      AerLost      AerWon%
# count  2921.000000  2921.000000  2921.000000  2921.000000  2921.000000
# mean      0.003451     7.410294     1.664286     1.858305    40.485861
# std       0.020306     3.650554     1.938046     2.245096    24.297290
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     5.070000     0.520000     0.840000    26.200000
# 50%       0.000000     7.380000     1.230000     1.390000    43.500000
# 75%       0.000000     9.380000     2.270000     2.210000    57.100000
# max       0.500000    40.000000    30.000000    40.000000   100.000000
#
# [8 rows x 138 columns]

# %% [markdown]
# ## Affichage de la première occurrence des lignes où le nom du joueur est dupliqué

# %%
dup = dataset.duplicated(subset='Player')
indexes_dup = list(dup[dup == True].index)
dataset.iloc[indexes_dup]
# Out:
#         Rk                     Player Nation   Pos       Squad  \
# 69      70                  Dele Alli    ENG  MFFW   Tottenham
# 82      83               Jordan Amavi    FRA    DF        Nice
# 86      87               Nadiem Amiri    GER  MFFW  Leverkusen
# 141    142  Pierre-Emerick Aubameyang    GAB    FW     Arsenal
# 219    220            Daniele Baselli    ITA    MF    Cagliari
# ...    ...                        ...    ...   ...         ...
# 2831  2832              Wout Weghorst    NED    FW   Wolfsburg
# 2859  2860                 Chris Wood    NZL    FW     Burnley
# 2872  2873               Okay Yoku�lu    TUR  DFMF      Getafe
# 2879  2880            Mattia Zaccagni    ITA    FW       Lazio
# 2883  2884              Denis Zakaria    SUI  MFDF  M'Gladbach
#
#                 Comp   Age  Born  MP  Starts  ...   Off   Crs  TklW  PKwon  \
# 69    Premier League  26.0  1996  10       8  ...  0.27  0.41  0.96   0.14
# 82           Ligue 1  28.0  1994   8       4  ...  0.00  1.52  1.09   0.00
# 86        Bundesliga  25.0  1996  13       3  ...  0.00  0.73  0.98   0.00
# 141   Premier League  32.0  1989  14      12  ...  0.87  0.78  0.61   0.00
# 219          Serie A  30.0  1992   9       2  ...  0.00  1.56  0.94   0.00
# ...              ...   ...   ...  ..     ...  ...   ...   ...   ...    ...
# 2831      Bundesliga  29.0  1992  18      17  ...  0.81  0.12  0.40   0.00
# 2859  Premier League  30.0  1991  17      17  ...  1.05  0.33  0.53   0.00
# 2872         La Liga  28.0  1994  11       5  ...  0.00  0.00  1.35   0.00
# 2879         Serie A  26.0  1995  29      21  ...  0.10  2.02  1.11   0.05
# 2883      Bundesliga  25.0  1996  16      15  ...  0.06  0.32  1.23   0.00
#
#       PKcon   OG  Recov  AerWon  AerLost  AerWon%
# 69     0.00  0.0   6.30    1.51     1.78     45.8
# 82     0.00  0.0  10.20    2.17     1.96     52.6
# 86     0.00  0.0   9.02    0.24     0.98     20.0
# 141    0.00  0.0   3.30    2.43     2.78     46.7
# 219    0.00  0.0  10.30    0.00     1.56      0.0
# ...     ...  ...    ...     ...      ...      ...
# 2831   0.00  0.0   4.74    3.12     2.66     54.0
# 2859   0.00  0.0   2.70    7.50     6.91     52.1
# 2872   0.00  0.0  11.00    3.08     1.35     69.6
# 2879   0.00  0.0   4.04    0.87     0.96     47.4
# 2883   0.06  0.0  10.90    0.90     0.97     48.3
#
# [135 rows x 143 columns]

# %%
dataset = dataset.drop_duplicates(subset=['Player', 'Rk'])
dataset.describe()
# Out:
#                 Rk          Age         Born           MP       Starts  \
# count  2921.000000  2920.000000  2921.000000  2921.000000  2921.000000
# mean   1461.000000    26.092123  1994.725094    18.800068    13.749743
# std     843.364393     4.641746    37.210426    11.619882    11.393763
# min       1.000000    16.000000     0.000000     1.000000     0.000000
# 25%     731.000000    23.000000  1992.000000     8.000000     3.000000
# 50%    1461.000000    26.000000  1996.000000    20.000000    12.000000
# 75%    2191.000000    29.000000  1999.000000    29.000000    23.000000
# max    2921.000000    41.000000  2006.000000    38.000000    38.000000
#
#                Min          90s        Goals        Shots          SoT  ...  \
# count  2921.000000  2921.000000  2921.000000  2921.000000  2921.000000  ...
# mean   1234.756248    13.719069     0.111274     1.220431     0.391462  ...
# std     977.941288    10.865255     0.233688     1.511266     0.784754  ...
# min       1.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%     307.000000     3.400000     0.000000     0.280000     0.000000  ...
# 50%    1102.000000    12.200000     0.000000     0.820000     0.190000  ...
# 75%    2025.000000    22.500000     0.150000     1.830000     0.560000  ...
# max    3420.000000    38.000000     5.000000    20.000000    20.000000  ...
#
#                Off          Crs         TklW       PKwon        PKcon  \
# count  2921.000000  2921.000000  2921.000000  2921.00000  2921.000000
# mean      0.195029     1.063708     1.026689     0.01519     0.013050
# std       0.509935     1.341177     1.028466     0.21167     0.052864
# min       0.000000     0.000000     0.000000     0.00000     0.000000
# 25%       0.000000     0.000000     0.430000     0.00000     0.000000
# 50%       0.000000     0.590000     0.920000     0.00000     0.000000
# 75%       0.200000     1.700000     1.410000     0.00000     0.000000
# max      10.000000    15.000000    10.000000    10.00000     1.430000
#
#                 OG        Recov       AerWon      AerLost      AerWon%
# count  2921.000000  2921.000000  2921.000000  2921.000000  2921.000000
# mean      0.003451     7.410294     1.664286     1.858305    40.485861
# std       0.020306     3.650554     1.938046     2.245096    24.297290
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     5.070000     0.520000     0.840000    26.200000
# 50%       0.000000     7.380000     1.230000     1.390000    43.500000
# 75%       0.000000     9.380000     2.270000     2.210000    57.100000
# max       0.500000    40.000000    30.000000    40.000000   100.000000
#
# [8 rows x 138 columns]

# %%
dataset.shape
# Out:
# (2921, 143)

# %% [markdown]
# ## Conversion des valeurs

# %%
# Affichage des types par colonnes
print(dataset.dtypes)
# Out:
# Rk           int64
# Player      object
# Nation      object
# Pos         object
# Squad       object
#             ...
# OG         float64
# Recov      float64
# AerWon     float64
# AerLost    float64
# AerWon%    float64
# Length: 143, dtype: object

# %%
dataset = dataset.convert_dtypes()
dataset.dtypes
# Out:
# Rk           Int64
# Player      string
# Nation      string
# Pos         string
# Squad       string
#             ...
# OG         Float64
# Recov      Float64
# AerWon     Float64
# AerLost    Float64
# AerWon%    Float64
# Length: 143, dtype: object

# %% [markdown]
# ## Vérification d'éléments *parasites*

# %% [markdown]
# ### Valeurs de types nulles

# %%
# On vérifie d'abord si au moins une valeur est nulle 
dataset.isnull().values.any()
# Out:
# True

# %%
# On affiche où sont les valeurs nulles
np.where(dataset.isnull())
# Out:
# (array([1531, 1531], dtype=int64), array([2, 6], dtype=int64))

# %%
# On compte le nombre de valeurs nulles
dataset.isnull().sum().sum()
# Out:
# 2

# %%
# On supprime les lignes qui contiennent nulles
dataset = dataset.dropna(axis=0)

# %%
dataset[dataset.notna()]
# Out:
#         Rk             Player Nation   Pos          Squad            Comp  \
# 0        1         Max Aarons    ENG    DF   Norwich City  Premier League
# 1        2   Yunis Abdelhamid    MAR    DF          Reims         Ligue 1
# 2        3  Salis Abdul Samed    GHA    MF  Clermont Foot         Ligue 1
# 3        4    Laurent Abergel    FRA    MF        Lorient         Ligue 1
# 4        5        Charles Abi    FRA    FW  Saint-Etienne         Ligue 1
# ...    ...                ...    ...   ...            ...             ...
# 2916  2917   Mart�n Zubimendi    ESP    MF  Real Sociedad         La Liga
# 2917  2918   Szymon ?urkowski    POL    MF         Empoli         Serie A
# 2918  2919    Martin �degaard    NOR    MF        Arsenal  Premier League
# 2919  2920        Milan ?uri?    BIH    FW    Salernitana         Serie A
# 2920  2921      Filip ?uri?i?    SRB  MFFW       Sassuolo         Serie A
#
#       Age  Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon    OG  Recov  \
# 0      22  2000  34      32  ...  0.03  1.41  1.16    0.0   0.06  0.03   5.53
# 1      34  1987  34      34  ...   0.0  0.06  1.39    0.0   0.03   0.0   6.77
# 2      22  2000  31      29  ...   0.0  0.36  1.24    0.0    0.0   0.0   8.76
# 3      29  1993  34      34  ...  0.03  0.79  2.23    0.0    0.0   0.0   8.87
# 4      22  2000   1       1  ...   0.0   2.0   0.0    0.0    0.0   0.0    4.0
# ...   ...   ...  ..     ...  ...   ...   ...   ...    ...    ...   ...    ...
# 2916   23  1999  36      26  ...   0.1   0.1  1.08    0.0    0.0   0.0   9.41
# 2917   24  1997  35      29  ...   0.0  0.74  1.91    0.0   0.04   0.0   8.05
# 2918   23  1998  36      32  ...   0.1  0.84  0.81    0.0   0.06   0.0   7.44
# 2919   32  1990  33      23  ...  0.25  0.29  0.17   0.04    0.0   0.0   3.24
# 2920   30  1992  12       9  ...  0.27   0.0  0.93    0.0    0.0   0.0   4.67
#
#       AerWon  AerLost  AerWon%
# 0       0.47     1.59     22.7
# 1       2.02     1.36     59.8
# 2       0.88     0.88     50.0
# 3       0.43     0.43     50.0
# 4        2.0      0.0    100.0
# ...      ...      ...      ...
# 2916    2.64     1.42     65.0
# 2917    1.02     1.56     39.4
# 2918    0.55     0.81     40.5
# 2919    12.4     4.81     72.0
# 2920     0.4     0.67     37.5
#
# [2920 rows x 143 columns]

# %% [markdown]
# ## Suppression de données non pertinentes pour le problème

# %% [markdown]
# ### Colonnes qui ne concernent pas directement le problème

# %%
# Liste à revoir
to_delete = ['Rk', 'Player', 'Nation', 'Squad', 'Age']
dataset = dataset.drop(columns=to_delete)

# %% [markdown]
# ### Colonnes à pourcentages

# %%
# On récupère la liste des colonnes dont le nom ne contient pas '%'
cols = [name for name in list(dataset.columns.values) if '%' not in name]
print(cols)
# Out:
# ['Pos', 'Comp', 'Born', 'MP', 'Starts', 'Min', '90s', 'Goals', 'Shots', 'SoT', 'G/Sh', 'G/SoT', 'ShoDist', 'ShoFK', 'ShoPK', 'PKatt', 'PasTotCmp', 'PasTotAtt', 'PasTotDist', 'PasTotPrgDist', 'PasShoCmp', 'PasShoAtt', 'PasMedCmp', 'PasMedAtt', 'PasLonCmp', 'PasLonAtt', 'Assists', 'PasAss', 'Pas3rd', 'PPA', 'CrsPA', 'PasProg', 'PasAtt', 'PasLive', 'PasDead', 'PasFK', 'TB', 'PasPress', 'Sw', 'PasCrs', 'CK', 'CkIn', 'CkOut', 'CkStr', 'PasGround', 'PasLow', 'PasHigh', 'PaswLeft', 'PaswRight', 'PaswHead', 'TI', 'PaswOther', 'PasCmp', 'PasOff', 'PasOut', 'PasInt', 'PasBlocks', 'SCA', 'ScaPassLive', 'ScaPassDead', 'ScaDrib', 'ScaSh', 'ScaFld', 'ScaDef', 'GCA', 'GcaPassLive', 'GcaPassDead', 'GcaDrib', 'GcaSh', 'GcaFld', 'GcaDef', 'Tkl', 'TklWon', 'TklDef3rd', 'TklMid3rd', 'TklAtt3rd', 'TklDri', 'TklDriAtt', 'TklDriPast', 'Press', 'PresSucc', 'PresDef3rd', 'PresMid3rd', 'PresAtt3rd', 'Blocks', 'BlkSh', 'BlkShSv', 'BlkPass', 'Int', 'Tkl+Int', 'Clr', 'Err', 'Touches', 'TouDefPen', 'TouDef3rd', 'TouMid3rd', 'TouAtt3rd', 'TouAttPen', 'TouLive', 'DriSucc', 'DriAtt', 'DriPast', 'DriMegs', 'Carries', 'CarTotDist', 'CarPrgDist', 'CarProg', 'Car3rd', 'CPA', 'CarMis', 'CarDis', 'RecTarg', 'Rec', 'RecProg', 'CrdY', 'CrdR', '2CrdY', 'Fls', 'Fld', 'Off', 'Crs', 'TklW', 'PKwon', 'PKcon', 'OG', 'Recov', 'AerWon', 'AerLost']

# %%
dataset = dataset.filter(items=cols)
dataset.shape
# Out:
# (2920, 128)

# %% [markdown]
# ### Ratios

# %%
cols = [name for name in list(dataset.columns.values) if '/' not in name]
print(cols)
# Out:
# ['Pos', 'Comp', 'Born', 'MP', 'Starts', 'Min', '90s', 'Goals', 'Shots', 'SoT', 'ShoDist', 'ShoFK', 'ShoPK', 'PKatt', 'PasTotCmp', 'PasTotAtt', 'PasTotDist', 'PasTotPrgDist', 'PasShoCmp', 'PasShoAtt', 'PasMedCmp', 'PasMedAtt', 'PasLonCmp', 'PasLonAtt', 'Assists', 'PasAss', 'Pas3rd', 'PPA', 'CrsPA', 'PasProg', 'PasAtt', 'PasLive', 'PasDead', 'PasFK', 'TB', 'PasPress', 'Sw', 'PasCrs', 'CK', 'CkIn', 'CkOut', 'CkStr', 'PasGround', 'PasLow', 'PasHigh', 'PaswLeft', 'PaswRight', 'PaswHead', 'TI', 'PaswOther', 'PasCmp', 'PasOff', 'PasOut', 'PasInt', 'PasBlocks', 'SCA', 'ScaPassLive', 'ScaPassDead', 'ScaDrib', 'ScaSh', 'ScaFld', 'ScaDef', 'GCA', 'GcaPassLive', 'GcaPassDead', 'GcaDrib', 'GcaSh', 'GcaFld', 'GcaDef', 'Tkl', 'TklWon', 'TklDef3rd', 'TklMid3rd', 'TklAtt3rd', 'TklDri', 'TklDriAtt', 'TklDriPast', 'Press', 'PresSucc', 'PresDef3rd', 'PresMid3rd', 'PresAtt3rd', 'Blocks', 'BlkSh', 'BlkShSv', 'BlkPass', 'Int', 'Tkl+Int', 'Clr', 'Err', 'Touches', 'TouDefPen', 'TouDef3rd', 'TouMid3rd', 'TouAtt3rd', 'TouAttPen', 'TouLive', 'DriSucc', 'DriAtt', 'DriPast', 'DriMegs', 'Carries', 'CarTotDist', 'CarPrgDist', 'CarProg', 'Car3rd', 'CPA', 'CarMis', 'CarDis', 'RecTarg', 'Rec', 'RecProg', 'CrdY', 'CrdR', '2CrdY', 'Fls', 'Fld', 'Off', 'Crs', 'TklW', 'PKwon', 'PKcon', 'OG', 'Recov', 'AerWon', 'AerLost']

# %%
dataset = dataset.filter(items=cols)
dataset.shape
# Out:
# (2920, 126)

# %% [markdown]
# ### Suppression des lignes avec le nombre de matchs joués inférieur ou égale à 5

# %%
# Liste des nombres de matchs joués
dataset['MP'][dataset['MP'] < 5]
# Out:
# 4       1
# 11      1
# 22      4
# 26      4
# 28      1
#        ..
# 2878    2
# 2889    1
# 2906    3
# 2912    4
# 2914    1
# Name: MP, Length: 514, dtype: Int64

# %%
# Suppression
dataset = dataset[dataset['MP'] > 5]
dataset
# Out:
#        Pos            Comp  Born  MP  Starts   Min   90s  Goals  Shots   SoT  \
# 0       DF  Premier League  2000  34      32  2881  32.0    0.0   0.41  0.06
# 1       DF         Ligue 1  1987  34      34  2983  33.1   0.06   0.54  0.18
# 2       MF         Ligue 1  2000  31      29  2462  27.4   0.04   0.66  0.18
# 3       MF         Ligue 1  1993  34      34  2956  32.8    0.0   0.91  0.21
# 5       FW      Bundesliga  1998  24       5   726   8.1    0.0   2.22  0.49
# ...    ...             ...   ...  ..     ...   ...   ...    ...    ...   ...
# 2916    MF         La Liga  1999  36      26  2591  28.8   0.07   0.73  0.35
# 2917    MF         Serie A  1997  35      29  2307  25.6   0.23   1.84  0.66
# 2918    MF  Premier League  1998  36      32  2785  30.9   0.23   1.72  0.68
# 2919    FW         Serie A  1990  33      23  2165  24.1   0.21   2.07  0.79
# 2920  MFFW         Serie A  1992  12       9   671   7.5   0.27    2.4  0.93
#
#       ...   Fld   Off   Crs  TklW  PKwon  PKcon    OG  Recov  AerWon  AerLost
# 0     ...  1.84  0.03  1.41  1.16    0.0   0.06  0.03   5.53    0.47     1.59
# 1     ...  0.73   0.0  0.06  1.39    0.0   0.03   0.0   6.77    2.02     1.36
# 2     ...  1.28   0.0  0.36  1.24    0.0    0.0   0.0   8.76    0.88     0.88
# 3     ...  2.07  0.03  0.79  2.23    0.0    0.0   0.0   8.87    0.43     0.43
# 5     ...  1.48  1.85  0.25  0.86    0.0    0.0   0.0   4.81    2.72     4.94
# ...   ...   ...   ...   ...   ...    ...    ...   ...    ...     ...      ...
# 2916  ...  0.83   0.1   0.1  1.08    0.0    0.0   0.0   9.41    2.64     1.42
# 2917  ...  2.85   0.0  0.74  1.91    0.0   0.04   0.0   8.05    1.02     1.56
# 2918  ...  0.74   0.1  0.84  0.81    0.0   0.06   0.0   7.44    0.55     0.81
# 2919  ...  1.99  0.25  0.29  0.17   0.04    0.0   0.0   3.24    12.4     4.81
# 2920  ...  2.13  0.27   0.0  0.93    0.0    0.0   0.0   4.67     0.4     0.67
#
# [2345 rows x 126 columns]

# %% [markdown]
# ### Autres raisons (plus ou moins arbitraires)
# Voir le [mini-rapport](./IAS-projet-validation.pdf) de validation

# %%
# Suppression des colonnes trop précises
too_detailed = ['90s', 'ShoDist', 'ShoFK', 'ShoPK', 'PKatt', 'PasTotDist' , 'PasTotPrgDist', 'PasShoCmp',
                'PasShoAtt', 'PasMedCmp', 'PasMedAtt', 'PasLonCmp', 'PasLonAtt', 'Pas3rd', 'PPA',
                'CrsPA', 'PasProg', 'PasLive', 'PasDead', 'PasFK', 'TB', 'Sw',  'CkIn', 'CkOut',
                'CkStr', 'PasGround', 'PasLow', 'PasHigh', 'PaswLeft', 'PaswRight', 'PaswHead',
                'PaswOther', 'ScaPassLive', 'ScaPassDead', 'ScaSh', 'ScaFld', 'ScaDef', 'GcaPassLive',
                'GcaPassDead', 'GcaSh', 'TklDef3rd', 'TklMid3rd', 'TklAtt3rd', 'TklDriAtt', 'Press',
                'PresSucc', 'PresDef3rd', 'PresMid3rd', 'PresAtt3rd', 'BlkSh', 'BlkShSv', 'BlkPass',
                'Tkl+Int', 'TouDefPen', 'TouDef3rd', 'TouMid3rd', 'TouAtt3rd', 'TouAttPen', 'TouLive',
                'DriAtt', 'DriMegs', 'CarTotDist', 'CarPrgDist', 'CarProg', 'Car3rd', 'CPA', 'CarMis',
                'CarDis', 'RecTarg', 'Rec', 'RecProg']
print(len(too_detailed))
dataset = dataset.drop(too_detailed, axis=1)
dataset.columns.values
# Out:
# 71
# array(['Pos', 'Comp', 'Born', 'MP', 'Starts', 'Min', 'Goals', 'Shots',
#        'SoT', 'PasTotCmp', 'PasTotAtt', 'Assists', 'PasAss', 'PasAtt',
#        'PasPress', 'PasCrs', 'CK', 'TI', 'PasCmp', 'PasOff', 'PasOut',
#        'PasInt', 'PasBlocks', 'SCA', 'ScaDrib', 'GCA', 'GcaDrib',
#        'GcaFld', 'GcaDef', 'Tkl', 'TklWon', 'TklDri', 'TklDriPast',
#        'Blocks', 'Int', 'Clr', 'Err', 'Touches', 'DriSucc', 'DriPast',
#        'Carries', 'CrdY', 'CrdR', '2CrdY', 'Fls', 'Fld', 'Off', 'Crs',
#        'TklW', 'PKwon', 'PKcon', 'OG', 'Recov', 'AerWon', 'AerLost'],
#       dtype=object)

# %% [markdown]
# # Encodage des données

# %%
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
from pandas import DataFrame
def get_cat_values(data: DataFrame, feature_name: str) -> list[str]:
    """Récupère les valeurs catégorielles à partir du nom de la colonne après un encodage 1-hot.\n
    En cas de encodage à k-1 valeurs, la valeur non explicite ne sera pas récupérée
    """
    feature = []
    for name in data.columns.values:
        if name.startswith(feature_name):
            feature.append(name)
    return [ft.replace(feature_name+"_", "") for ft in feature]

# %%
# Position du joueur
get_cat_values(dataset, "Pos")
# Out:
# ['DFFW', 'DFMF', 'FW', 'FWDF', 'FWMF', 'GK', 'GKMF', 'MF', 'MFDF', 'MFFW']

# %%
# Championnat du club du joueur
get_cat_values(dataset, "Comp")
# Out:
# ['La Liga', 'Ligue 1', 'Premier League', 'Serie A']

# %% [markdown]
# # Visualisation

# %% [markdown]
# ## Valeurs catégorielles

# %%
# On rappelle la liste des features
print(dataset.columns.values, f"Nombre de features : {len(dataset.columns.values)}", sep="\n")
# Out:
# ['Born' 'MP' 'Starts' 'Min' 'Goals' 'Shots' 'SoT' 'PasTotCmp' 'PasTotAtt'
#  'Assists' 'PasAss' 'PasAtt' 'PasPress' 'PasCrs' 'CK' 'TI' 'PasCmp'
#  'PasOff' 'PasOut' 'PasInt' 'PasBlocks' 'SCA' 'ScaDrib' 'GCA' 'GcaDrib'
#  'GcaFld' 'GcaDef' 'Tkl' 'TklWon' 'TklDri' 'TklDriPast' 'Blocks' 'Int'
#  'Clr' 'Err' 'Touches' 'DriSucc' 'DriPast' 'Carries' 'CrdY' 'CrdR' '2CrdY'
#  'Fls' 'Fld' 'Off' 'Crs' 'TklW' 'PKwon' 'PKcon' 'OG' 'Recov' 'AerWon'
#  'AerLost' 'Pos_DFFW' 'Pos_DFMF' 'Pos_FW' 'Pos_FWDF' 'Pos_FWMF' 'Pos_GK'
#  'Pos_GKMF' 'Pos_MF' 'Pos_MFDF' 'Pos_MFFW' 'Comp_La Liga' 'Comp_Ligue 1'
#  'Comp_Premier League' 'Comp_Serie A']
# Nombre de features : 67

# %% [markdown]
# Il y en a beaucoup...

# %%
ligues = (len(dataset[dataset['Comp_La Liga'] == 1]),
len(dataset[dataset['Comp_Ligue 1'] == 1]),
len(dataset[dataset['Comp_Premier League'] == 1]),
len(dataset[dataset['Comp_Serie A'] == 1]))
ligues
# Out:
# (500, 481, 444, 505)

# %% [markdown]
# ### Répartition des joueurs dans les 5 grands championnats

# %%
total_joueurs = dataset.shape[0]
nb_par_champ = dict(zip(get_cat_values(dataset, "Comp"), ligues))
# On ajoute la Bundesliga, retiré après le 1-hot
nb_par_champ["Bundesliga"] = total_joueurs - sum(ligues)
nb_par_champ
# Out:
# {'La Liga': 500,
#  'Ligue 1': 481,
#  'Premier League': 444,
#  'Serie A': 505,
#  'Bundesliga': 415}

# %%
fig, ax = plt.subplots()
# Taille de l'image
fig.set_size_inches(7,7)
# Etiquettes avec associations nom de la ligue - pourcentage du total (après nettoyage et encodage)
perc_labels = [f"{cmp} : {round(nb_par_champ[cmp]/total_joueurs*100, 2)}%" for cmp in nb_par_champ]
# Diagramme circulaire
ax.pie(nb_par_champ.values(), frame=True, center=(4,4), radius=2, labels=perc_labels)
# Paramétrages des axes
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()

# %% [markdown]
# On peut comparer avec le dataset d'origine

# %%
filename = 'dataset.csv'
df_orig = pd.read_csv(filename, sep=";", header=0)
champ_names = ["Premier League", "Ligue 1", "La Liga", "Bundesliga", "Serie A"]
nbpc = {cmp: len(df_orig[df_orig['Comp'] == cmp]) for cmp in champ_names}

fig, ax = plt.subplots()
# Taille de l'image
fig.set_size_inches(7,7)
# Diagramme circulaire
ax.pie(nb_par_champ.values(), frame=True, center=(4,4), radius=2, labels=[f"{cmp} : {round(nbpc[cmp]/total_joueurs*100, 2)}%" for cmp in nbpc])
# Paramétrages des axes
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()

# %%
# Affichage des joueurs retirés par championnats
for k1 in nb_par_champ:
    print(f"{k1} : {nbpc[k1] - nb_par_champ[k1]}")
# Out:
# La Liga : 117
# Ligue 1 : 122
# Premier League : 102
# Serie A : 127
# Bundesliga : 108

# %% [markdown]
# On remarque bien que l'on a retiré les valeurs de manière équilibrée par rapport à la répartition entre chaque championnat

# %% [markdown]
# ### Répartition des joueurs au niveau des postes

# %%
postes_prev = set(df_orig['Pos'])
postes_prev
# Out:
# {'DF',
#  'DFFW',
#  'DFMF',
#  'FW',
#  'FWDF',
#  'FWMF',
#  'GK',
#  'GKMF',
#  'MF',
#  'MFDF',
#  'MFFW'}

# %%
noms_postes = get_cat_values(dataset, "Pos")
postes = {nom: len(dataset[dataset["Pos_"+nom] == 1]) for nom in noms_postes}
postes["DF"] = dataset.shape[0] -  sum(postes.values())
postes
# Out:
# {'DFFW': 26,
#  'DFMF': 57,
#  'FW': 297,
#  'FWDF': 20,
#  'FWMF': 271,
#  'GK': 144,
#  'GKMF': 1,
#  'MF': 486,
#  'MFDF': 55,
#  'MFFW': 209,
#  'DF': 779}

# %% [markdown]
# On remarque déjà qu'il n'y a qu'une seule occurrence pour le poste de GKMF (GoalKeeper Midfielder ?).
# On le supprimera plus tard dans le dataset car trop rare.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12,12)
perc_labels = [f"{p} : {round(postes[p]/dataset.shape[0]*100, 2)}%" for p in postes]
ax.pie(postes.values(), frame=True, center=(4,4), radius=2, labels=perc_labels)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()

# %% [markdown]
# On remarque plusieurs choses :
# - le poste de défenseur (`DF`) est prédominante, suivi de milieu de terrain (`MF`) et de arrière latéral-défenseur latéral
# - il y a des mélanges de postes pour indiquer (on imagine) que le joueur peut occuper/a déjà occupé plusieurs postes ou rôles (voire de manière fréquente)

# %% [markdown]
# ## Quelques valeurs numériques

# %% [markdown]
# ### Buts, passes décisives, arrêts

# %%
dataset.filter(['Goals','Assists', 'Blocks'])
# Out:
#       Goals  Assists  Blocks
# 0       0.0     0.06    2.69
# 1      0.06      0.0    1.87
# 2      0.04      0.0    0.99
# 3       0.0     0.06    1.68
# 5       0.0     0.12    1.23
# ...     ...      ...     ...
# 2916   0.07     0.03    1.35
# 2917   0.23     0.08    2.03
# 2918   0.23     0.13    0.58
# 2919   0.21     0.17    0.41
# 2920   0.27     0.13     1.2
#
# [2345 rows x 3 columns]

# %%
plt.style.use('_mpl-gallery')

# Diagramme de dispersion
player_numbers = list(dataset.iloc[:, 0])
xs = list(dataset['Goals'])
ys = list(dataset['Assists'])
zs = list(dataset['Blocks'])
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.set_size_inches(10,10)
remarquables = []
ax.scatter(xs, ys, zs, c='#000', marker='x')
for infos in zip(player_numbers, xs, ys, zs):
    if infos[1] >= 1 or infos[2] >= 1.5 or infos[3] >= 5 or (infos[1] >= 1 and infos[2] >= 1):
        remarquables.append(infos[0])
        ax.text(infos[1], infos[2], infos[3], str(infos[0]), fontdict={"fontsize": 12, "color": "blue"}, zdir='x')
# for infos in zip(xs, ys, zs):
#     ax.text(infos[0], infos[1], infos[2], f"Joueur n° {0}", fontdict={"fontsize": 12, "color": "r"}, zdir='x')
    
ax.set_xlabel("Goals")
ax.set_ylabel("Assists")
ax.set_zlabel("Blocks")
ax.view_init(20, 60)
fig.tight_layout()
plt.show()

# %% [markdown]
# # Système de score
# Plutôt que de directement partir du jeu de données pour réaliser la tâche que l'on a définit au départ,
# on va plutôt définir un système de score qui associera à chaque joueur un score sur lequel l'apprentissage sera appliqué.
# Ce score sera défini par un ensemble nouveau de colonnes qui correspond aux features auxquels on a associé un poids.
#
# Par exemple : en considérant les buts comme très positives à l'appréciation du joueur et les fautes comme pénalisants, on peut ainsi
# appliquer les calculs suivants :
# - score des buts = 3 * le nombre de but
# - score des fautes = 2 * le nombre de fautes

# %%
df_orig[np.in1d(df_orig['Rk'], remarquables)]
# Out:
#         Rk            Player Nation   Pos        Squad            Comp   Age  \
# 1987  1988         Dani Olmo    ESP    MF   RB Leipzig      Bundesliga  24.0
# 1990  1991       Jonas Omlin    SUI    GK  Montpellier         Ligue 1  28.0
# 1993  1994        Jean Onana    CMR    MF     Bordeaux         Ligue 1  22.0
# 1994  1995     Karim Onisiwo    AUT    FW     Mainz 05      Bundesliga  30.0
# 1995  1996  Javier Ontiveros    ESP  MFFW      Osasuna         La Liga  24.0
# 1996  1997     Tyler Onyango    ENG  MFFW      Everton  Premier League  19.0
# 1997  1998      Frank Onyeka    NGA    MF    Brentford  Premier League  24.0
# 1999  2000      Divock Origi    BEL    FW    Liverpool  Premier League  27.0
# 2001  2002     Stefan Ortega    GER    GK      Arminia      Bundesliga  29.0
#
#       Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon   OG  Recov  \
# 1987  1998  19       7  ...  0.12  0.72  0.96   0.00    0.0  0.0   8.55
# 1990  1994  29      29  ...  0.00  0.00  0.00   0.00    0.0  0.0   5.09
# 1993  2000  23      23  ...  0.05  0.49  2.79   0.00    0.0  0.0  10.80
# 1994  1992  31      28  ...  1.03  2.14  0.46   0.00    0.0  0.0   4.50
# 1995  1997   3       0  ...  0.00  5.00  0.00   0.00    0.0  0.0  12.50
# 1996  2003   3       0  ...  0.00  0.00  0.00   0.00    0.0  0.0   3.33
# 1997  1998  20      12  ...  0.00  0.60  1.38   0.09    0.0  0.0   8.19
# 1999  1995   7       0  ...  0.00  0.67  0.00   0.00    0.0  0.0   8.00
# 2001  1992  33      33  ...  0.00  0.00  0.00   0.00    0.0  0.0   6.03
#
#       AerWon  AerLost  AerWon%
# 1987    1.08     1.33     45.0
# 1990    0.00     0.00      0.0
# 1993    2.50     1.47     63.0
# 1994    2.75     4.85     36.2
# 1995    0.00     0.00      0.0
# 1996    3.33     3.33     50.0
# 1997    1.29     2.16     37.5
# 1999    2.00     3.33     37.5
# 2001    0.00     0.03      0.0
#
# [9 rows x 143 columns]

# %%
df_orig[np.logical_and(df_orig['Assists'] >= 0.5, df_orig['MP'] > 15)][['Player', 'MP', 'Assists']]
# Out:
#                    Player  MP  Assists
# 657   Romain Del Castillo  19     0.56
# 669       Ousmane Demb�l�  21     0.83
# 1445     Dejan Kulusevski  18     0.57
# 1720        Kylian Mbapp�  35     0.54
# 1774         Lionel Messi  26     0.59
# 1806    Aleksei Miranchuk  19     0.58
# 1869        Thomas M�ller  32     0.63
# 2149           Paul Pogba  20     0.60
# 2426   Kingsley Schindler  18     0.51
# 2586        Isaac Success  22     0.59
